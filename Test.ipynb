# %%
from Algorithms import MEAStar, MACO, AStar
import networkx as nx
import pickle
from typing import List, Set, Tuple, Dict
import numpy as np
import matplotlib.pyplot as plt

# %%
def import_graph_pickle(filename='rack_network.gpickle'):
    """
    Import graph from pickle format.
    
    Args:
        filename: Input filename
    
    Returns:
        NetworkX graph
    """
    with open(filename, 'rb') as f:
        G = pickle.load(f)
    print(f"Graph loaded from {filename}")
    print(f"Nodes: {G.number_of_nodes()}, Edges: {G.number_of_edges()}")
    return G

# %%
G_combined = import_graph_pickle("Intermediate Outputs/3d connected network.gpickle")
# Out:
# Graph loaded from Intermediate Outputs/3d connected network.gpickle
# Nodes: 66, Edges: 444

# %%
from Algorithms import MEAStar, MACO, AStar

# %%
mea_star = MEAStar(G_combined)
path1 = mea_star.find_path(1, 20)
# Out:
# 0  -  108.44653351314196
# 0  -  452.65721543278124
# 0  -  427.0139329919137
# 0  -  379.5628672959968
# 108.44653351314196  -  108.44653351314196
# 108.44653351314196  -  427.0139329919137
# 108.44653351314196  -  379.5628672959968
# 216.89306702628392  -  108.44653351314196
# 216.89306702628392  -  427.0139329919137
# 216.89306702628392  -  379.5628672959968
# 325.3396005394259  -  108.44653351314196
# 325.3396005394259  -  427.0139329919137
# 325.3396005394259  -  379.5628672959968
# 433.78613405256783  -  108.44653351314196
# 433.78613405256783  -  427.0139329919137
# 433.78613405256783  -  379.5628672959968
# 542.2326675657098  -  108.44653351314196
# 542.2326675657098  -  427.0139329919137
# 542.2326675657098  -  379.5628672959968
# 650.6792010788517  -  108.44653351314196
# 650.6792010788517  -  427.0139329919137
# 650.6792010788517  -  379.5628672959968
# 759.1257345919937  -  379.5628672959968
# 1138.6886018879904  -  452.65721543278124
# ...

# %%
if path1:
    print(f"Path found: {path1}")
    print(f"Path length: {len(path1[0])} nodes")
else:
    print("No path found")
# Out:
# Path found: ([1, 10, 19, 20], 962.4743994969693)
# Path length: 4 nodes

# %%
if path1:
    print(f"Path found: {path1}")
    print(f"Path length: {len(path1[0])} nodes")
else:
    print("No path found")
# Out:
# Path found: (None, None)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 if path1:
#       2     print(f"Path found: {path1}")
# ----> 3     print(f"Path length: {len(path1[0])} nodes")
#       4 else:
#       5     print("No path found")
#
# TypeError: object of type 'NoneType' has no len()

# %%
a_star = AStar(G_combined)
path2 = a_star.find_path(1, 20)

# %%
if path2:
    print(f"Path found: {path2}")
    print(f"Path length: {len(path2[0])} nodes")
else:
    print("No path found")
# Out:
# Path found: ([1, 2, 11, 20], 962.4743994969692)
# Path length: 4 nodes

# %% [markdown]
# ## Create Cost Matrix for ACO

# %%
def create_cost_matrix(mea_star_instance, nodes: List) -> Tuple[np.ndarray, List, Dict]:
    """
    Create a cost matrix for a given set of nodes using MEA* algorithm.
    Nodes 0 and 100 are automatically included regardless of input.
    
    Args:
        mea_star_instance: Instance of MEAStar class with a graph loaded
        nodes: List of node IDs to include in the matrix
        
    Returns:
        Tuple containing:
        - cost_matrix: numpy array of shape (n, n) with costs between nodes
        - node_list: ordered list of nodes (matches matrix indices)
        - node_to_index: dictionary mapping node ID to matrix index
    """
    # Ensure nodes 0 and 100 are included
    node_set = set(nodes)
    node_set.add(0)
    node_set.add(100)
    
    # Convert to sorted list for consistent ordering
    node_list = sorted(list(node_set))
    
    # Create mapping from node ID to matrix index
    node_to_index = {node: idx for idx, node in enumerate(node_list)}
    
    # Get number of nodes
    n = len(node_list)
    
    # Initialize cost matrix with infinity
    cost_matrix = np.full((n, n), np.inf)
    
    # Set diagonal to 0 (cost from node to itself)
    np.fill_diagonal(cost_matrix, 0)
    
    # Calculate costs between all pairs of nodes
    print(f"Calculating cost matrix for {n} nodes...")
    
    for i, start_node in enumerate(node_list):
        for j, end_node in enumerate(node_list):
            if i == j:
                continue  # Skip diagonal (already set to 0)
            
            # Find path and cost using MEA*
            path, cost = mea_star_instance.find_path(start_node, end_node)
            print(start_node, " - ", end_node, ' - ', cost)
            
            if path is not None:
                cost_matrix[i, j] = cost
            else:
                # If no path exists, keep as infinity
                cost_matrix[i, j] = np.inf
            
            # Optional: print progress
            if (i * n + j + 1) % 10 == 0:
                print(f"Progress: {i * n + j + 1}/{n * n} paths calculated")
    
    print("Cost matrix calculation complete!")
    
    return cost_matrix, node_list, node_to_index


def print_cost_matrix_info(cost_matrix: np.ndarray, node_list: List, node_to_index: Dict):
    """
    Print information about the cost matrix for verification.
    
    Args:
        cost_matrix: The cost matrix
        node_list: List of nodes
        node_to_index: Mapping from node to index
    """
    print(f"\nCost Matrix Shape: {cost_matrix.shape}")
    print(f"Nodes included: {node_list}")
    print(f"\nNode to Index Mapping:")
    for node, idx in sorted(node_to_index.items()):
        print(f"  Node {node} -> Index {idx}")
    
    print(f"\nSample costs:")
    print(f"  Cost from node 0 to node 100: {cost_matrix[node_to_index[0], node_to_index[100]]}")
    
    # Show nodes with no path (infinite cost)
    inf_count = np.isinf(cost_matrix).sum() - len(node_list)  # Exclude diagonal
    print(f"\nNumber of unreachable node pairs: {inf_count}")

# %%
# Create cost matrix for specific nodes (0 and 100 will be added automatically)
selected_nodes = [8, 12, 27, 31]
cost_matrix, node_list, node_to_index = create_cost_matrix(mea_star, selected_nodes)

# Print information
print_cost_matrix_info(cost_matrix, node_list, node_to_index)
# Out:
# Calculating cost matrix for 6 nodes...
# 0  -  8  -  648.7172148615896
# 0  -  12  -  540.9642560378064
# 0  -  27  -  893.0859013941309
# 0  -  31  -  1217.4445088249258
# 0  -  100  -  2047.2560105720843
# 8  -  0  -  648.7172148615896
# 8  -  12  -  540.9642560378064
# 8  -  27  -  1055.2652051095286
# Progress: 10/36 paths calculated
# 8  -  31  -  730.9065976787336
# 8  -  100  -  932.530996363535
# 12  -  0  -  573.7607581707425
# 12  -  8  -  573.7607581707425
# 12  -  27  -  514.300949071722
# 12  -  31  -  676.4802527871194
# 12  -  100  -  2458.8374650274295
# 27  -  0  -  991.4754077929392
# 27  -  8  -  1153.6547115083367
# Progress: 20/36 paths calculated
# 27  -  12  -  579.8939533375942
# 27  -  31  -  324.3586074307948
# 27  -  100  -  2876.552114649626
# 31  -  0  -  1315.8340152237342
# 31  -  8  -  829.2961040775419
# 31  -  12  -  742.0732570529915
# 31  -  27  -  324.3586074307948
# 31  -  100  -  3200.9107220804212
# Progress: 30/36 paths calculated
# ...

# %%
np.savetxt('Intermediate Outputs/data.csv', cost_matrix, delimiter=',')

# %%
# Create MACO instance
maco = MACO(
    graph=G_combined,
    n_ants=10,
    n_iterations=50,
    alpha=1.0,
    beta=2.0,
    p=100.0
)

# Find optimal path
best_path, best_cost = maco.optimize(start=1, goal=119)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 12
#       2 maco = MACO(
#       3     graph=G_combined,
#       4     n_ants=10,
#    (...)      8     p=100.0
#       9 )
#      11 # Find optimal path
# ---> 12 best_path, best_cost = maco.optimize(start=1, goal=119)
#
# AttributeError: 'MACO' object has no attribute 'optimize'

# %%
import networkx as nx
from typing import List

def build_reduced_digraph(
    astar: AStar,
    node_list: List[int]
) -> nx.DiGraph:

    reduced_nodes = set(node_list)
    reduced_nodes.update([0, 100])

    G_full = astar.graph   # or whatever graph A* is using
    G_reduced = nx.DiGraph()

    # Copy nodes WITH attributes
    for n in reduced_nodes:
        if n in G_full.nodes:
            G_reduced.add_node(n, **G_full.nodes[n])
        else:
            G_reduced.add_node(n)

    # Directed: run A* for every ordered pair
    for u in reduced_nodes:
        for v in reduced_nodes:
            if u == v:
                continue

            path, cost = astar.find_path(u, v)
            if path is not None and cost is not None:
                G_reduced.add_edge(u, v, cost=cost)

    return G_reduced

# %%
a_star = AStar(G_combined)
mea_star = MEAStar(G_combined)

important_nodes = [127, 30, 27, 6]
G_small = build_reduced_digraph(mea_star, important_nodes)

# %%
import matplotlib.pyplot as plt
import networkx as nx

def visualize_directed_graph(G: nx.DiGraph):
    plt.figure(figsize=(10, 8))

    # Layout: spring works well for weighted directed graphs
    pos = nx.spring_layout(G, seed=42)

    # Draw nodes
    nx.draw_networkx_nodes(
        G, pos,
        node_size=800,
        node_color="lightblue"
    )

    # Draw directed edges
    nx.draw_networkx_edges(
        G, pos,
        arrowstyle="->",
        arrowsize=15,
        edge_color="gray",
        width=1.5
    )

    # Draw node labels
    nx.draw_networkx_labels(
        G, pos,
        font_size=10,
        font_weight="bold"
    )

    # Edge labels (weights)
    edge_labels = {
        (u, v): f"{d['cost']:.2f}"
        for u, v, d in G.edges(data=True)
    }

    nx.draw_networkx_edge_labels(
        G, pos,
        edge_labels=edge_labels,
        font_size=9
    )

    plt.title("Reduced Directed Graph with A* Path Costs")
    plt.axis("off")
    plt.tight_layout()
    plt.show()

# %%
visualize_directed_graph(G_small)

# %%
def export_graph_pickle(G, filename='rack_network.gpickle'):
    """
    Export graph to pickle format (preserves all NetworkX attributes).
    Recommended for Python-to-Python use.

    Args:
        G: NetworkX graph
        filename: Output filename (default: 'rack_network.gpickle')
    """
    with open(filename, 'wb') as f:
        pickle.dump(G, f, pickle.HIGHEST_PROTOCOL)
    print(f"Graph exported to {filename}")

base_filename1 = "test_network(1,2,8)"
export_graph_pickle(G_combined, f"Intermediate Outputs/{base_filename1}.gpickle")
# Out:
# Graph exported to Intermediate Outputs/test_network(1,2,8).gpickle

# %%
# Create MACO instance
maco = MACO(
    graph=G_small,
    n_ants=6,
    n_iterations=200,
    alpha=1.0,
    beta=1.0,
    p=0.95
)

# Find optimal path
best_path, best_cost = maco.solve_tsp()

# %%
print(best_path)
print(f'{best_cost}')
# Out:
# [100, 127, 27, 30, 6, 0]
# 3927.2270094464297

# %% [markdown]
# ## Control function

# %%
import networkx as nx
import numpy as np


def solve_distance_path(G, nodes_to_visit):
    """
    Finds the shortest physical distance path visiting all nodes_to_visit.
    Uses x, y, z coordinates from the graph metadata.
    """
    # 1. Ensure start/end at node 0
    if 0 not in nodes_to_visit:
        nodes_to_visit = [0] + list(nodes_to_visit)

    # 2. Add Euclidean distance as a weight to all edges
    # Based on x, y, z attributes found in rack 1.gpickle
    for u, v, data in G.edges(data=True):
        pos_u = np.array([G.nodes[u]['x'], G.nodes[u]['y'], G.nodes[u]['z']])
        pos_v = np.array([G.nodes[v]['x'], G.nodes[v]['y'], G.nodes[v]['z']])
        dist = np.linalg.norm(pos_u - pos_v)
        G[u][v]['dist'] = dist

    # 3. Find the optimal visiting order (TSP) using physical distance
    # networkx uses an approximation for TSP
    visit_order = nx.approximation.traveling_salesman_problem(
        G, nodes=nodes_to_visit, weight='dist', cycle=True
    )

    # 4. Expand to the FULL node-by-node path
    # If the TSP says 0 -> 3, this finds if it must go 0 -> 1 -> 2 -> 3
    full_path = []
    total_distance = 0

    print("Path Details:")
    for i in range(len(visit_order) - 1):
        u, v = visit_order[i], visit_order[i + 1]

        # Get the shortest path based on distance between these two target nodes
        sub_path = nx.shortest_path(G, source=u, target=v, weight='dist')
        sub_dist = nx.shortest_path_length(G, source=u, target=v, weight='dist')

        # Add to full path (avoiding duplicating the connecting node)
        if i == 0:
            full_path.extend(sub_path)
        else:
            full_path.extend(sub_path[1:])

        print(f"Segment {u} to {v}: Path={sub_path}, Distance={sub_dist:.2f}")
        total_distance += sub_dist

    return full_path, total_distance

# Example Usage:
# path, dist = solve_distance_path(G, [1, 3])
# print(f"Full Path: {path}")
# print(f"Total Distance: {dist}")

# %%
mea_star = MEAStar(G_combined)
nodes = mea_star.get_neighbors(11, 20)

# %%
node = 11
x = G_combined.nodes[node]['x']
y = G_combined.nodes[node]['y']
z = G_combined.nodes[node]['z']

print("node:", node)
print(f"({x}, {y}, {z})")
# Out:
# node: 11
# (160.0, 0, 160.0)

# %%
for node in nodes:
    x = G_combined.nodes[node]['x']
    y = G_combined.nodes[node]['y']
    z = G_combined.nodes[node]['z']

    print("node:", node)
    print(f"({x}, {y}, {z})")
# Out:
# node: 2
# (80.0, 0, 0.0)
# node: 3
# (160.0, 0, 0.0)
# node: 4
# (240.0, 0, 0.0)
# node: 10
# (80.0, 0, 160.0)
# node: 12
# (240.0, 0, 160.0)
# node: 19
# (160.0, 0, 320.0)
# node: 20
# (240.0, 0, 320.0)
# node: 18
# (80.0, 0, 320.0)
# node: 111
# (160.0, 280.0, 160.0)

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.cm as cm

def create_3d_rack_diagram():
    """Create a 3D visualization of nodes with given coordinates"""

    # Node data: node_id: (x, y, z)
    nodes = {
        2: (80.0, 0, 0.0),
        3: (160.0, 0, 0.0),
        4: (240.0, 0, 0.0),
        10: (80.0, 0, 160.0),
        11: (160.0, 0, 160.0),
        12: (240.0, 0, 160.0),
        19: (160.0, 0, 320.0),
        20: (240.0, 0, 320.0),
        18: (80.0, 0, 320.0),
        111: (160.0, 280.0, 160.0)
    }

    # Create figure with 3D plot
    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111, projection='3d')

    # Prepare data for plotting
    node_ids = list(nodes.keys())
    coords = list(nodes.values())
    x_coords = [coord[0] for coord in coords]
    y_coords = [coord[1] for coord in coords]
    z_coords = [coord[2] for coord in coords]

    # Color nodes by height (y-coordinate)
    colors = cm.viridis(np.array(y_coords) / max(y_coords))

    # 3D Plot - plot nodes with larger size for source node 11
    node_sizes = [250 if node_id == 11 else 200 for node_id in node_ids]
    scatter3d = ax.scatter(x_coords, y_coords, z_coords,
                           c=colors, s=node_sizes, alpha=0.8, edgecolors='black', linewidth=2)

    # Define connections from node 11 with specific colors
    connections = {
        'horizontal': {'nodes': [10, 12], 'color': 'blue'},
        'vertical_up': {'nodes': [19], 'color': 'green'},
        'vertical_down': {'nodes': [3], 'color': 'red'},
        'diagonal_up': {'nodes': [18, 20], 'color': 'orange'},
        'diagonal_down': {'nodes': [2, 4], 'color': 'purple'},
        'inter_rack': {'nodes': [111], 'color': 'cyan'}
    }

    # Draw arrows from node 11 to other nodes
    source_node = 11
    source_coords = nodes[source_node]

    # Arrow length scale factor (shorter to not overlap nodes)
    arrow_scale = 0.95

    # Draw arrows for each connection type
    for conn_type, conn_info in connections.items():
        for target_node in conn_info['nodes']:
            target_coords = nodes[target_node]

            # Calculate direction vector
            dx = target_coords[0] - source_coords[0]
            dy = target_coords[1] - source_coords[1]
            dz = target_coords[2] - source_coords[2]

            # Scale down the vector so arrow doesn't reach the target node
            scaled_dx = dx * arrow_scale
            scaled_dy = dy * arrow_scale
            scaled_dz = dz * arrow_scale

            # Draw arrow from source to scaled position
            ax.quiver(source_coords[0], source_coords[1], source_coords[2],
                     scaled_dx, scaled_dy, scaled_dz,
                     color=conn_info['color'],
                     arrow_length_ratio=0.15,
                     linewidth=2,
                     alpha=0.8)

    # Add labels to 3D plot with offset
    label_offset = 25  # Offset distance for labels

    for node_id, (x, y, z) in nodes.items():
        # Calculate offset direction based on node position relative to center
        center_x, center_y, center_z = 160, 140, 160  # Approximate center

        # Calculate direction vector from center to node
        dir_x = x - center_x
        dir_y = y - center_y
        dir_z = z - center_z

        # Normalize the direction vector
        length = np.sqrt(dir_x**2 + dir_y**2 + dir_z**2)
        if length > 0:
            dir_x /= length
            dir_y /= length
            dir_z /= length

        # Apply offset
        label_x = x + dir_x
        label_y = y + dir_y * label_offset
        label_z = z + dir_z * label_offset

        ax.text(label_x, label_y, label_z, f'{node_id}',
               fontsize=10, fontweight='bold',
               ha='center', va='center')

    # Remove axis
    ax.set_axis_off()

    # Adjust view
    ax.view_init(elev=20, azim=45)

    plt.tight_layout()
    plt.savefig('Intermediate Outputs/drone path example.png', dpi=300, bbox_inches='tight')
    plt.show()

    return nodes, connections

# Main execution
if __name__ == "__main__":
    nodes, connections = create_3d_rack_diagram()

    # Print connection information
    print("Connections from Node 11:")
    print("-" * 40)
    for conn_type, conn_info in connections.items():
        nodes_list = conn_info['nodes']
        color = conn_info['color']
        print(f"{conn_type.replace('_', ' ').title():15} -> Nodes {nodes_list} (Color: {color})")
# Out:
# Connections from Node 11:
# ----------------------------------------
# Horizontal      -> Nodes [10, 12] (Color: blue)
# Vertical Up     -> Nodes [19] (Color: green)
# Vertical Down   -> Nodes [3] (Color: red)
# Diagonal Up     -> Nodes [18, 20] (Color: orange)
# Diagonal Down   -> Nodes [2, 4] (Color: purple)
# Inter Rack      -> Nodes [111] (Color: cyan)

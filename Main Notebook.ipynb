# %% [markdown]
# # ENERGY-AWARE ROUTE OPTIMIZATION FOR UAV- UGV SYSTEMS IN COLD STORAGE WAREHOUSES
#
# Name - Anuda Wewalage <br/>
# Index No - 211495N <br/>
# Department - Transport Management & Logistics Engineering <br/>
# Supervisor - Prof. Amila Thibbotuwawa <br/>
# External Advisor : - Kasuni Weerasinghe <br/>

# %% [markdown]
# ### Import Libraries

# %%
import networkx as nx
import pickle
from typing import List, Set, Tuple, Dict
# import numpy as np
# import matplotlib.pyplot as plt

from Algorithms import MEAStar, MACO, AStar
import Experiment as expt

# %% [markdown]
# ## Import the Network
# - This Network represent a two single selective rack on both sides of an isle.
# - Each rack contains 32 pallet positions.
# - Pallet positions in rack1 numbered 1 - 32 and rack 2 numbered 101 - 132
# - 0 and 100 are positions that UGV can reach for deploying the drone.

# %%
def import_graph_pickle(filename='rack_network.gpickle'):
    """
    Import graph from pickle format.

    Args:
        filename: Input filename

    Returns:
        NetworkX graph
    """
    with open(filename, 'rb') as f:
        G = pickle.load(f)
    print(f"Graph loaded from {filename}")
    print(f"Nodes: {G.number_of_nodes()}, Edges: {G.number_of_edges()}")
    return G

G_combined = import_graph_pickle("Intermediate Outputs/3d connected network.gpickle")
G_rack1 = import_graph_pickle("Intermediate Outputs/rack 1.gpickle")
G_rack2 = import_graph_pickle("Intermediate Outputs/rack 2.gpickle")
# Out:
# Graph loaded from Intermediate Outputs/3d connected network.gpickle
# Nodes: 66, Edges: 444
# Graph loaded from Intermediate Outputs/rack 1.gpickle
# Nodes: 66, Edges: 444
# Graph loaded from Intermediate Outputs/rack 2.gpickle
# Nodes: 66, Edges: 444

# %% [markdown]
# ## Experiment - Routing Algorithm
#
# For the experiment, I create list of Random nodes and tested for 3 different scenarios.
# 1. for 4 nodes - usually for this level, Algorithm provide same output even run several times. So, we take data by running algorithm only once.
# 2. for 8 and 16 nodes - This level, algorithm gives different routes in multiple runs. So, we run optimal path algorithm once (since it is not a heuristic based algorithm) and other algorithms 50 times. Then take the average for the analyzis.

# %%
import pandas as pd
import time
import os
from datetime import datetime

# %%
# create objects
mea_star = MEAStar(G_combined)
a_star = AStar(G_combined)

# %%
# Get user inputs
num_nodes = int(input("Enter number of nodes: "))
num_experiments = int(input("Enter number of experiments: "))

# Generate nodes once (outside the loop)
selected_nodes = expt.generate_unique_random_nodes_explicit(num_nodes)

# Initialize results list
results = []

#Check for old model (2d VRP) approach
start_time_ssp = time.time()
path1_ssp_tent, path2_ssp_tent, cost_ssp = expt.find_optimal_path_for_mixed_racks(selected_nodes, G_rack1, G_rack2)

time_ssp = time.time() - start_time_ssp

path1_ssp = [node for node in path1_ssp_tent if node in set(selected_nodes)]
path2_ssp = [node for node in path2_ssp_tent if node in set(selected_nodes)]

columns = ['expt_id', 'timestamp', 'selected_nodes', 'time_ssp', 'path1_ssp', 'path2_ssp', 'cost_ssp']

file_path = 'Output/Experiment_log.csv'

if os.path.exists(file_path):
    df = pd.read_csv(file_path)
    # Determine next expt_id
    if not df.empty and 'expt_id' in df.columns:
        # Get the maximum existing expt_id and add 1
        last_id = df['expt_id'].max()
        next_id = int(last_id) + 1
    else:
        # Start from 1001 if file exists but no expt_id column or empty
        next_id = 1001
else:
    # Create new DataFrame starting from 1001
    df = pd.DataFrame(columns=columns)
    next_id = 1001

# Create new row
new_row = {
    'expt_id': next_id,
    'timestamp': datetime.now().strftime('%Y-%m-%d %H:%M:%S'),
    'selected_nodes': str(selected_nodes),
    'time_ssp': time_ssp,
    'path1_ssp': str(path1_ssp),
    'path2_ssp': str(path2_ssp),
    'cost_ssp': cost_ssp
}

# FIX: Convert to list of lists and create new DataFrame
# Convert existing df to list of dictionaries
if not df.empty:
    records = df.to_dict('records')
else:
    records = []

# Add new row
records.append(new_row)

# Create new DataFrame from all records
df = pd.DataFrame(records, columns=columns)

df.to_csv(file_path, index=False)

print(f"Experiment data added to {file_path} with expt_id: {next_id}")

# Main experiment loop
for experiment_no in range(1, num_experiments + 1):
    print(f"\n--- Running Experiment {experiment_no}/{num_experiments} ---")

    # ===== MEA_STAR Algorithm =====
    start_time_mea = time.time()

    # Build reduced graph with mea_star
    G_small_mea = expt.build_reduced_digraph(mea_star, selected_nodes)

    # Run MACO
    maco_mea = MACO(
        graph=G_small_mea,
        n_ants=6,
        n_iterations=200,
        alpha=1.0,
        beta=1.0,
        p=0.95
    )

    # Find optimal path
    path_maco_mea, cost_maco_mea = maco_mea.solve_tsp()

    time_maco_mea = time.time() - start_time_mea

    print(f"MEA_STAR - Cost: {cost_maco_mea:.4f}, Time: {time_maco_mea:.4f}s")

    # ===== A_STAR Algorithm =====
    start_time_astar = time.time()

    # Build reduced graph with a_star
    G_small_astar = expt.build_reduced_digraph(a_star, selected_nodes)

    # Run MACO
    maco_astar = MACO(
        graph=G_small_astar,
        n_ants=6,
        n_iterations=200,
        alpha=1.0,
        beta=1.0,
        p=0.95
    )

    # Find optimal path
    path_maco_astar, cost_maco_astar = maco_astar.solve_tsp()

    time_maco_astar = time.time() - start_time_astar

    print(f"A_STAR - Cost: {cost_maco_astar:.4f}, Time: {time_maco_astar:.4f}s")

    # ===== Record Results =====
    results.append({
        'experiment_no': experiment_no,
        'no_of_nodes': num_nodes,
        'node_list': selected_nodes,
        'cost_maco_mea': cost_maco_mea,
        'path_maco_mea': path_maco_mea,
        'time_maco_mea': time_maco_mea,
        'cost_maco_astar': cost_maco_astar,
        'path_maco_astar': path_maco_astar,
        'time_maco_astar': time_maco_astar
    })

# Create DataFrame
df_results = pd.DataFrame(results)

# Display results
print("\n" + "="*80)
print("EXPERIMENT RESULTS")
print("="*80)
print(df_results.to_string(index=False))

# Save to CSV
output_filename = f'Output/{next_id}_maco_experiments_{num_nodes}nodes_{num_experiments}runs.csv'
df_results.to_csv(output_filename, index=False)
print(f"\nResults saved to: {output_filename}")
# Out:
# Experiment data added to Output/Experiment_log.csv with expt_id: 1060
#
# --- Running Experiment 1/50 ---
# MEA_STAR - Cost: 8647.8706, Time: 1.3359s
# A_STAR - Cost: 8673.4738, Time: 1.4109s
#
# --- Running Experiment 2/50 ---
#
# --- Running Experiment 42/50 ---
# MEA_STAR - Cost: 8480.8770, Time: 1.4879s
# A_STAR - Cost: 8889.0199, Time: 1.4599s
#
# --- Running Experiment 43/50 ---
# MEA_STAR - Cost: 8757.6641, Time: 1.3867s
# A_STAR - Cost: 8970.4761, Time: 1.4277s
#
# --- Running Experiment 44/50 ---
# MEA_STAR - Cost: 8371.0434, Time: 1.4394s
# A_STAR - Cost: 8726.1474, Time: 1.4542s
#
# --- Running Experiment 45/50 ---
# MEA_STAR - Cost: 8783.3074, Time: 1.4084s
# A_STAR - Cost: 8539.4240, Time: 1.4562s
#
# --- Running Experiment 46/50 ---
# MEA_STAR - Cost: 8509.2544, Time: 1.3965s
# A_STAR - Cost: 9157.1995, Time: 1.4147s
#
# --- Running Experiment 47/50 ---
# MEA_STAR - Cost: 8944.5902, Time: 1.3989s
# A_STAR - Cost: 9103.1788, Time: 1.4860s
#
# --- Running Experiment 48/50 ---
# MEA_STAR - Cost: 8920.3339, Time: 1.4146s
# A_STAR - Cost: 9406.9963, Time: 1.4414s
#
# --- Running Experiment 49/50 ---
# MEA_STAR - Cost: 8729.0842, Time: 1.4624s
# A_STAR - Cost: 8158.2715, Time: 1.4408s
#
# --- Running Experiment 50/50 ---
# MEA_STAR - Cost: 9164.4599, Time: 1.4163s
# A_STAR - Cost: 9271.3168, Time: 1.4691s
#
# ================================================================================
# EXPERIMENT RESULTS
# ================================================================================
#  experiment_no  no_of_nodes                                                              node_list  cost_maco_mea                                                                    path_maco_mea  time_maco_mea  cost_maco_astar                                                                  path_maco_astar  time_maco_astar
#              1           16 [13, 120, 19, 31, 23, 26, 24, 104, 32, 107, 119, 14, 15, 20, 112, 110]    8647.870563     [0, 104, 107, 110, 112, 120, 119, 19, 23, 13, 32, 31, 24, 14, 15, 26, 20, 0]       1.335867      8673.473824 [100, 104, 110, 112, 13, 14, 32, 31, 20, 15, 19, 26, 119, 120, 23, 24, 107, 100]         1.410929
#              2           16 [13, 120, 19, 31, 23, 26, 24, 104, 32, 107, 119, 14, 15, 20, 112, 110]    8810.540363   [0, 110, 119, 120, 107, 104, 112, 23, 32, 31, 20, 26, 19, 24, 14, 13, 15, 100]       1.434976      9110.236681   [100, 104, 107, 120, 119, 23, 20, 15, 14, 24, 31, 32, 19, 13, 112, 110, 26, 0]         1.447835
#              3           16 [13, 120, 19, 31, 23, 26, 24, 104, 32, 107, 119, 14, 15, 20, 112, 110]    8129.894116   [100, 120, 26, 119, 112, 110, 104, 107, 13, 14, 15, 24, 32, 31, 23, 19, 20, 0]       1.402389      9053.076712   [0, 14, 13, 15, 23, 104, 107, 24, 31, 32, 26, 112, 19, 20, 120, 119, 110, 100]         1.465923
#              4           16 [13, 120, 19, 31, 23, 26, 24, 104, 32, 107, 119, 14, 15, 20, 112, 110]    8401.010450 [100, 107, 104, 112, 110, 120, 119, 19, 31, 32, 24, 15, 13, 20, 14, 23, 26, 100]       1.399017      8806.176578   [0, 110, 112, 104, 13, 14, 15, 20, 19, 119, 23, 32, 24, 31, 26, 120, 107, 100]         1.424481
#              5           16 [13, 120, 19, 31, 23, 26, 24, 104, 32, 107, 119, 14, 15, 20, 112, 110]    8998.610824   [0, 104, 107, 19, 20, 119, 120, 110, 14, 32, 31, 26, 23, 24, 15, 13, 112, 100]       1.384635      8974.557203   [100, 112, 110, 104, 107, 119, 15, 13, 20, 32, 31, 26, 19, 120, 23, 24, 14, 0]         1.428217
#              6           16 [13, 120, 19, 31, 23, 26, 24, 104, 32, 107, 119, 14, 15, 20, 112, 110]    
#
# Results saved to: Output/1060_maco_experiments_16nodes_50runs.csv

# %%
# for single runs
for i in range(20):
    # Get user inputs
    num_nodes = 4
    num_experiments = 1

    # Generate nodes once (outside the loop)
    selected_nodes = expt.generate_unique_random_nodes_explicit(num_nodes)

    # Initialize results list
    results = []

    #Check for old model (2d VRP) approach
    start_time_ssp = time.time()
    path1_ssp_tent, path2_ssp_tent, cost_ssp = expt.find_optimal_path_for_mixed_racks(selected_nodes, G_rack1, G_rack2)

    time_ssp = time.time() - start_time_ssp

    path1_ssp = [node for node in path1_ssp_tent if node in set(selected_nodes)]
    path2_ssp = [node for node in path2_ssp_tent if node in set(selected_nodes)]

    columns = ['expt_id', 'timestamp', 'selected_nodes', 'time_ssp', 'path1_ssp', 'path2_ssp', 'cost_ssp']

    file_path = 'Output/Experiment_log.csv'

    if os.path.exists(file_path):
        df = pd.read_csv(file_path)
        # Determine next expt_id
        if not df.empty and 'expt_id' in df.columns:
            # Get the maximum existing expt_id and add 1
            last_id = df['expt_id'].max()
            next_id = int(last_id) + 1
        else:
            # Start from 1001 if file exists but no expt_id column or empty
            next_id = 1001
    else:
        # Create new DataFrame starting from 1001
        df = pd.DataFrame(columns=columns)
        next_id = 1001

    # Create new row
    new_row = {
        'expt_id': next_id,
        'timestamp': datetime.now().strftime('%Y-%m-%d %H:%M:%S'),
        'selected_nodes': str(selected_nodes),
        'time_ssp': time_ssp,
        'path1_ssp': str(path1_ssp),
        'path2_ssp': str(path2_ssp),
        'cost_ssp': cost_ssp
    }

    # FIX: Convert to list of lists and create new DataFrame
    # Convert existing df to list of dictionaries
    if not df.empty:
        records = df.to_dict('records')
    else:
        records = []

    # Add new row
    records.append(new_row)

    # Create new DataFrame from all records
    df = pd.DataFrame(records, columns=columns)

    df.to_csv(file_path, index=False)

    print(f"Experiment data added to {file_path} with expt_id: {next_id}")

    # Main experiment loop
    for experiment_no in range(1, num_experiments + 1):
        print(f"\n--- Running Experiment {experiment_no}/{num_experiments} ---")

        # ===== MEA_STAR Algorithm =====
        start_time_mea = time.time()

        # Build reduced graph with mea_star
        G_small_mea = expt.build_reduced_digraph(mea_star, selected_nodes)

        # Run MACO
        maco_mea = MACO(
            graph=G_small_mea,
            n_ants=6,
            n_iterations=200,
            alpha=1.0,
            beta=1.0,
            p=0.95
        )

        # Find optimal path
        path_maco_mea, cost_maco_mea = maco_mea.solve_tsp()

        time_maco_mea = time.time() - start_time_mea

        print(f"MEA_STAR - Cost: {cost_maco_mea:.4f}, Time: {time_maco_mea:.4f}s")

        # ===== A_STAR Algorithm =====
        start_time_astar = time.time()

        # Build reduced graph with a_star
        G_small_astar = expt.build_reduced_digraph(a_star, selected_nodes)

        # Run MACO
        maco_astar = MACO(
            graph=G_small_astar,
            n_ants=6,
            n_iterations=200,
            alpha=1.0,
            beta=1.0,
            p=0.95
        )

        # Find optimal path
        path_maco_astar, cost_maco_astar = maco_astar.solve_tsp()

        time_maco_astar = time.time() - start_time_astar

        print(f"A_STAR - Cost: {cost_maco_astar:.4f}, Time: {time_maco_astar:.4f}s")

        # ===== Record Results =====
        results.append({
            'experiment_no': experiment_no,
            'no_of_nodes': num_nodes,
            'node_list': selected_nodes,
            'cost_maco_mea': cost_maco_mea,
            'path_maco_mea': path_maco_mea,
            'time_maco_mea': time_maco_mea,
            'cost_maco_astar': cost_maco_astar,
            'path_maco_astar': path_maco_astar,
            'time_maco_astar': time_maco_astar
        })

    # Create DataFrame
    df_results = pd.DataFrame(results)

    # Display results
    print("\n" + "="*80)
    print("EXPERIMENT RESULTS")
    print("="*80)
    print(df_results.to_string(index=False))

    # Save to CSV
    output_filename = f'Output/{next_id}_maco_experiments_{num_nodes}nodes_{num_experiments}runs.csv'
    df_results.to_csv(output_filename, index=False)
    print(f"\nResults saved to: {output_filename}")
# Out:
# Experiment data added to Output/Experiment_log.csv with expt_id: 1001
#
# --- Running Experiment 1/1 ---
# MEA_STAR - Cost: 3794.5243, Time: 0.2882s
# A_STAR - Cost: 3794.5243, Time: 0.3284s
#
# ================================================================================
# EXPERIMENT RESULTS
# ================================================================================
#  experiment_no  no_of_nodes       node_list  cost_maco_mea         path_maco_mea  time_maco_mea  cost_maco_astar       path_maco_astar  time_maco_astar
#              1            4 [16, 25, 20, 1]    3794.524255 [0, 1, 25, 20, 16, 0]       0.288157      3794.524255 [0, 1, 25, 20, 16, 0]         0.328375
#
# Results saved to: Output/1001_maco_experiments_4nodes_1runs.csv
# Experiment data added to Output/Experiment_log.csv with expt_id: 1002
#
# --- Running Experiment 1/1 ---
# MEA_STAR - Cost: 4174.0871, Time: 0.3259s
# A_STAR - Cost: 4174.0871, Time: 0.3418s
#
# ================================================================================
# EXPERIMENT RESULTS
# ================================================================================
#  experiment_no  no_of_nodes          node_list  cost_maco_mea              path_maco_mea  time_maco_mea  cost_maco_astar            path_maco_astar  time_maco_astar
#              1            4 [105, 103, 24, 25]    4174.087122 [0, 25, 24, 105, 103, 100]       0.325905      4174.087122 [0, 25, 24, 105, 103, 100]         0.341823
#
# Results saved to: Output/1002_maco_experiments_4nodes_1runs.csv
# Experiment data added to Output/Experiment_log.csv with expt_id: 1003
#
# --- Running Experiment 1/1 ---
# MEA_STAR - Cost: 3577.6312, Time: 0.3321s
# A_STAR - Cost: 3577.6312, Time: 0.3473s
#
# ================================================================================
# EXPERIMENT RESULTS
# ================================================================================
#  experiment_no  no_of_nodes     node_list  cost_maco_mea       path_maco_mea  time_maco_mea  cost_maco_astar     path_maco_astar  time_maco_astar
#              1            4 [30, 8, 7, 5]    3577.631188 [0, 5, 7, 8, 30, 0]        0.33215      3577.631188 [0, 5, 7, 8, 30, 0]         0.347336
#
# Results saved to: Output/1003_maco_experiments_4nodes_1runs.csv
# Experiment data added to Output/Experiment_log.csv with expt_id: 1004
#
# --- Running Experiment 1/1 ---
# MEA_STAR - Cost: 3957.1941, Time: 0.3377s
# A_STAR - Cost: 3957.1941, Time: 0.3503s
#
# ================================================================================
# EXPERIMENT RESULTS
# ================================================================================
#  experiment_no  no_of_nodes          node_list  cost_maco_mea              path_maco_mea  time_maco_mea  cost_maco_astar            path_maco_astar  time_maco_astar
#              1            4 [132, 24, 121, 23]    3957.194055 [0, 23, 24, 132, 121, 100]       0.337695      3957.194055 [0, 23, 24, 132, 121, 100]         0.350258
#
# Results saved to: Output/1004_maco_experiments_4nodes_1runs.csv
# Experiment data added to Output/Experiment_log.csv with expt_id: 1005
#
# --- Running Experiment 1/1 ---
# MEA_STAR - Cost: 3740.3010, Time: 0.3726s
# A_STAR - Cost: 3740.3010, Time: 0.3601s
#
# ================================================================================
# EXPERIMENT RESULTS
# ================================================================================
#  experiment_no  no_of_nodes         node_list  cost_maco_mea             path_maco_mea  time_maco_mea  cost_maco_astar           path_maco_astar  time_maco_astar
#              1            4 [27, 12, 127, 15]    3740.300988 [100, 127, 27, 15, 12, 0]       0.372581      3740.300988 [100, 127, 27, 15, 12, 0]         0.360113
#
# Results saved to: Output/1005_maco_experiments_4nodes_1runs.csv
# Experiment data added to Output/Experiment_log.csv with expt_id: 1006
#
# --- Running Experiment 1/1 ---
# MEA_STAR - Cost: 3577.6312, Time: 0.3395s
# A_STAR - Cost: 3577.6312, Time: 0.3282s
#
# ================================================================================
# EXPERIMENT RESULTS
# ================================================================================
#  experiment_no  no_of_nodes            node_list  cost_maco_mea                  path_maco_mea  time_maco_mea  cost_maco_astar                path_maco_astar  time_maco_astar
#              1            4 [107, 115, 106, 126]    3577.631188 [100, 106, 107, 115, 126, 100]       0.339475      3577.631188 [100, 106, 107, 115, 126, 100]         0.328162
#
# Results saved to: Output/1006_maco_experiments_4nodes_1runs.csv
# Experiment data added to Output/Experiment_log.csv with expt_id: 1007
#
# --- Running Experiment 1/1 ---
# MEA_STAR - Cost: 3523.4079, Time: 0.3633s
# A_STAR - Cost: 3523.4079, Time: 0.3200s
#
# ================================================================================
# EXPERIMENT RESULTS
# ================================================================================
#  experiment_no  no_of_nodes          node_list  cost_maco_mea              path_maco_mea  time_maco_mea  cost_maco_astar            path_maco_astar  time_maco_astar
#              1            4 [21, 25, 119, 121]    3523.407921 [0, 25, 21, 121, 119, 100]        0.36334      3523.407921 [0, 25, 21, 121, 119, 100]         0.320009
#
# Results saved to: Output/1007_maco_experiments_4nodes_1runs.csv
# Experiment data added to Output/Experiment_log.csv with expt_id: 1008
#
# --- Running Experiment 1/1 ---
# MEA_STAR - Cost: 2574.3794, Time: 0.3132s
# A_STAR - Cost: 2574.3794, Time: 0.3107s
#
# ================================================================================
# EXPERIMENT RESULTS
# ================================================================================
#  experiment_no  no_of_nodes      node_list  cost_maco_mea        path_maco_mea  time_maco_mea  cost_maco_astar      path_maco_astar  time_maco_astar
#              1            4 [18, 12, 3, 6]    2574.379442 [0, 18, 12, 6, 3, 0]       0.313168      2574.379442 [0, 18, 12, 6, 3, 0]         0.310727
#
# Results saved to: Output/1008_maco_experiments_4nodes_1runs.csv
# Experiment data added to Output/Experiment_log.csv with expt_id: 1009
#
# --- Running Experiment 1/1 ---
# MEA_STAR - Cost: 2953.9423, Time: 0.3234s
# A_STAR - Cost: 2953.9423, Time: 0.3144s
#
# ================================================================================
# EXPERIMENT RESULTS
# ================================================================================
#  experiment_no  no_of_nodes          node_list  cost_maco_mea              path_maco_mea  time_maco_mea  cost_maco_astar            path_maco_astar  time_maco_astar
#              1            4 [2, 122, 104, 105]    2953.942309 [0, 2, 104, 105, 122, 100]       0.323391      2953.942309 [0, 2, 104, 105, 122, 100]         0.314446
#
# Results saved to: Output/1009_maco_experiments_4nodes_1runs.csv
# Experiment data added to Output/Experiment_log.csv with expt_id: 1010
#
# --- Running Experiment 1/1 ---
# MEA_STAR - Cost: 2467.2799, Time: 0.3055s
# A_STAR - Cost: 2467.2799, Time: 0.3028s
#
# ================================================================================
# EXPERIMENT RESULTS
# ================================================================================
#  experiment_no  no_of_nodes         node_list  cost_maco_mea             path_maco_mea  time_maco_mea  cost_maco_astar           path_maco_astar  time_maco_astar
#              1            4 [106, 107, 6, 12]    2467.279948 [0, 12, 6, 106, 107, 100]       0.305491      2467.279948 [100, 106, 107, 6, 12, 0]         0.302792
#
# Results saved to: Output/1010_maco_experiments_4nodes_1runs.csv
# Experiment data added to Output/Experiment_log.csv with expt_id: 1011
#
# --- Running Experiment 1/1 ---
# MEA_STAR - Cost: 2819.8525, Time: 0.3102s
# A_STAR - Cost: 2819.8525, Time: 0.3256s
#
# ================================================================================
# EXPERIMENT RESULTS
# ================================================================================
#  experiment_no  no_of_nodes       node_list  cost_maco_mea           path_maco_mea  time_maco_mea  cost_maco_astar         path_maco_astar  time_maco_astar
#              1            4 [20, 4, 111, 6]    2819.852493 [0, 4, 6, 20, 111, 100]       0.310189      2819.852493 [0, 4, 6, 20, 111, 100]         0.325556
#
# Results saved to: Output/1011_maco_experiments_4nodes_1runs.csv
# Experiment data added to Output/Experiment_log.csv with expt_id: 1012
#
# --- Running Experiment 1/1 ---
# MEA_STAR - Cost: 3253.6386, Time: 0.3142s
# A_STAR - Cost: 3253.6386, Time: 0.3113s
#
# ================================================================================
# EXPERIMENT RESULTS
# ================================================================================
#  experiment_no  no_of_nodes         node_list  cost_maco_mea             path_maco_mea  time_maco_mea  cost_maco_astar           path_maco_astar  time_maco_astar
#              1            4 [3, 124, 120, 23]    3253.638627 [0, 3, 23, 124, 120, 100]       0.314165      3253.638627 [0, 3, 23, 124, 120, 100]         0.311286
#
# Results saved to: Output/1012_maco_experiments_4nodes_1runs.csv
# Experiment data added to Output/Experiment_log.csv with expt_id: 1013
#
# --- Running Experiment 1/1 ---
# MEA_STAR - Cost: 2819.8525, Time: 0.3311s
# A_STAR - Cost: 2819.8525, Time: 0.2997s
#
# ================================================================================
# EXPERIMENT RESULTS
# ================================================================================
#  experiment_no  no_of_nodes          node_list  cost_maco_mea              path_maco_mea  time_maco_mea  cost_maco_astar            path_maco_astar  time_maco_astar
#              1            4 [21, 104, 105, 12]    2819.852493 [0, 21, 12, 105, 104, 100]       0.331059      2819.852493 [100, 104, 105, 21, 12, 0]         0.299661
#
# Results saved to: Output/1013_maco_experiments_4nodes_1runs.csv
# Experiment data added to Output/Experiment_log.csv with expt_id: 1014
#
# --- Running Experiment 1/1 ---
# MEA_STAR - Cost: 4091.2839, Time: 0.3140s
# A_STAR - Cost: 4039.9973, Time: 0.3213s
#
# ================================================================================
# EXPERIMENT RESULTS
# ================================================================================
#  experiment_no  no_of_nodes          node_list  cost_maco_mea              path_maco_mea  time_maco_mea  cost_maco_astar            path_maco_astar  time_maco_astar
#              1            4 [16, 117, 129, 13]    4091.283871 [100, 117, 129, 16, 13, 0]       0.313952      4039.997306 [0, 13, 16, 129, 117, 100]         0.321254
#
# Results saved to: Output/1014_maco_experiments_4nodes_1runs.csv
# Experiment data added to Output/Experiment_log.csv with expt_id: 1015
#
# --- Running Experiment 1/1 ---
# MEA_STAR - Cost: 4361.0131, Time: 0.2903s
# A_STAR - Cost: 4361.0131, Time: 0.3169s
#
# ================================================================================
# EXPERIMENT RESULTS
# ================================================================================
#  experiment_no  no_of_nodes         node_list  cost_maco_mea             path_maco_mea  time_maco_mea  cost_maco_astar           path_maco_astar  time_maco_astar
#              1            4 [15, 126, 104, 9]    4361.013143 [100, 104, 126, 15, 9, 0]       0.290325      4361.013143 [100, 104, 126, 15, 9, 0]         0.316922
#
# Results saved to: Output/1015_maco_experiments_4nodes_1runs.csv
# Experiment data added to Output/Experiment_log.csv with expt_id: 1016
#
# --- Running Experiment 1/1 ---
# MEA_STAR - Cost: 3823.1042, Time: 0.3047s
# A_STAR - Cost: 3823.1042, Time: 0.2954s
#
# ================================================================================
# EXPERIMENT RESULTS
# ================================================================================
#  experiment_no  no_of_nodes          node_list  cost_maco_mea              path_maco_mea  time_maco_mea  cost_maco_astar            path_maco_astar  time_maco_astar
#              1            4 [111, 132, 23, 11]    3823.104239 [100, 111, 132, 23, 11, 0]        0.30468      3823.104239 [0, 11, 23, 132, 111, 100]         0.295411
#
# Results saved to: Output/1016_maco_experiments_4nodes_1runs.csv
# Experiment data added to Output/Experiment_log.csv with expt_id: 1017
#
# --- Running Experiment 1/1 ---
# MEA_STAR - Cost: 3740.3010, Time: 0.3095s
# A_STAR - Cost: 3740.3010, Time: 0.3321s
#
# ================================================================================
# EXPERIMENT RESULTS
# ================================================================================
#  experiment_no  no_of_nodes          node_list  cost_maco_mea              path_maco_mea  time_maco_mea  cost_maco_astar            path_maco_astar  time_maco_astar
#              1            4 [102, 30, 19, 106]    3740.300988 [100, 102, 106, 30, 19, 0]        0.30953      3740.300988 [100, 102, 106, 30, 19, 0]         0.332086
#
# Results saved to: Output/1017_maco_experiments_4nodes_1runs.csv
# Experiment data added to Output/Experiment_log.csv with expt_id: 1018
#
# --- Running Experiment 1/1 ---
# MEA_STAR - Cost: 3957.1941, Time: 0.3094s
# A_STAR - Cost: 3957.1941, Time: 0.3006s
#
# ================================================================================
# EXPERIMENT RESULTS
# ================================================================================
#  experiment_no  no_of_nodes        node_list  cost_maco_mea            path_maco_mea  time_maco_mea  cost_maco_astar          path_maco_astar  time_maco_astar
#              1            4 [6, 1, 122, 125]    3957.194055 [100, 125, 122, 6, 1, 0]       0.309374      3957.194055 [100, 125, 122, 6, 1, 0]         0.300587
#
# Results saved to: Output/1018_maco_experiments_4nodes_1runs.csv
# Experiment data added to Output/Experiment_log.csv with expt_id: 1019
#
# --- Running Experiment 1/1 ---
# MEA_STAR - Cost: 3763.1701, Time: 0.3130s
# A_STAR - Cost: 3657.4977, Time: 0.3129s
#
# ================================================================================
# EXPERIMENT RESULTS
# ================================================================================
#  experiment_no  no_of_nodes        node_list  cost_maco_mea            path_maco_mea  time_maco_mea  cost_maco_astar          path_maco_astar  time_maco_astar
#              1            4 [10, 129, 14, 9]    3763.170148 [100, 129, 14, 10, 9, 0]        0.31301      3657.497737 [0, 9, 10, 14, 129, 100]         0.312946
#
# Results saved to: Output/1019_maco_experiments_4nodes_1runs.csv
# Experiment data added to Output/Experiment_log.csv with expt_id: 1020
#
# --- Running Experiment 1/1 ---
# MEA_STAR - Cost: 3470.5317, Time: 0.3118s
# A_STAR - Cost: 3470.5317, Time: 0.3068s
#
# ================================================================================
# EXPERIMENT RESULTS
# ================================================================================
#  experiment_no  no_of_nodes         node_list  cost_maco_mea             path_maco_mea  time_maco_mea  cost_maco_astar           path_maco_astar  time_maco_astar
#              1            4 [2, 24, 121, 114]    3470.531694 [0, 2, 24, 121, 114, 100]       0.311787      3470.531694 [0, 2, 24, 121, 114, 100]         0.306753
#
# Results saved to: Output/1020_maco_experiments_4nodes_1runs.csv
